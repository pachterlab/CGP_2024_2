# %% [markdown]
# ## **Import packages for analysis**

# %%
import sys
sys.path.insert(0, '/home/tchari/monod/src/') #OR pip install monod

# %%
import monod
from monod import preprocess, extract_data, cme_toolbox, inference, analysis

# %%
import pandas as pd
import numpy as np
import loompy as lp
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
import scipy.stats

from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, ExtraTreesRegressor, RandomForestRegressor
from sklearn.model_selection import train_test_split, ShuffleSplit
from sklearn.metrics import accuracy_score, classification_report

import os

# import hdbscan
import sklearn

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## **Import data and metadata**

# %%
#metadata
# !wget --content-disposition https://github.com/pachterlab/CGP_2024_2/raw/main/metadata/stoch_metadata.tar.gz 
# !tar -xvf stoch_metadata.tar.gz
# Out:
# ./D0D3FullSeq/Day3/outs/filtered_feature_bc_matrix/barcodes.tsv
# ./D0D3FullSeq/Day0/outs/filtered_feature_bc_matrix/barcodes.tsv
# norman_GSE133344_filtered_cell_identities.csv

# %%
#gene length annotation
# !wget --content-disposition https://github.com/pachterlab/CGP_2024_2/raw/main/reference/gg_200525_genome_polyA_cum_3

# %%
#read in loom files
# !wget --content-disposition https://data.caltech.edu/records/ahjyk-gsj16/files/allcrispr_looms.tar.gz?download=1
# !tar -xvf allcrispr_looms.tar.gz
# Out:
# allcrispr.loom

# %%
meta_path = "./"
meta = pd.read_csv(meta_path+'norman_GSE133344_filtered_cell_identities.csv')

#'guide_identity'

# %%
meta.head()
# Out:
#          cell_barcode                    guide_identity  read_count  \
# 0  TTGAACGAGACTCGGA-2  ARID1A_NegCtrl0__ARID1A_NegCtrl0       28684
# 1  CGTTGGGGTGTTTGTG-7  BCORL1_NegCtrl0__BCORL1_NegCtrl0       18367
# 2  GAACCTAAGTGTTAGA-6      FOSB_NegCtrl0__FOSB_NegCtrl0       16296
# 3  CCTTCCCTCCGTCATC-4                SET_KLF1__SET_KLF1       16262
# 4  TCAATCTGTCTTTCAT-2      OSR2_NegCtrl0__OSR2_NegCtrl0       16057
#
#    UMI_count   coverage  gemgroup  good_coverage  number_of_cells
# 0       1809  15.856274         2           True                1
# 1        896  20.498884         7           True                1
# 2        664  24.542169         6           True                1
# 3        850  19.131765         4           True                1
# 4       1067  15.048735         2           True                2

# %%
ids = list(meta['guide_identity'].value_counts().index)
counts = list(meta['guide_identity'].value_counts())

saveCounts = pd.DataFrame()
saveCounts['guide_identity'] = ids
saveCounts['cells'] = counts

# %% [markdown]
# Select for all guides/conditions with > 50 cells

# %%
filt_ids = list(saveCounts['guide_identity'][saveCounts['cells'] >  50])
len(filt_ids)
# Out:
# 290

# %% [markdown]
# Set up output files + paths to looms for the different guide conditions for *Monod*

# %%
dataset_meta = ['allcrispr']
print('dataset_meta: ', dataset_meta)
print()

subcluster_names = [[i] for i in filt_ids]

sub_names_only = ['_'.join(n) for n in subcluster_names]

cluster_names = []
dataset_names = ['norman_'+dataset_meta[0]+'_'+y  for y in sub_names_only]   #To save
#print('dataset_names: ', dataset_names)
print('len(dataset_names): ',len(dataset_names))
print()

raw_data_locations = [dataset_meta[0] for y in sub_names_only]
transcriptome_filepath = './gg_200525_genome_polyA_cum_3'

spliced_layer = 'spliced'
unspliced_layer = 'unspliced'
gene_attr = 'gene_name'
cell_attr = 'barcode'

attribute_names=[(unspliced_layer,spliced_layer),gene_attr,cell_attr]

loom_filepaths = ['./'+x+'.loom' for x in raw_data_locations] 
#print('loom_filepaths: ',loom_filepaths)

n_datasets = len(loom_filepaths)
# Out:
# dataset_meta:  ['allcrispr']
#
# len(dataset_names):  290

# %% [markdown]
# ## **Cell Preprocessing**
#
# Filter for cell barcodes with enough UMIs

# %%
cf = []
thr_lb = [1e4]*len(dataset_meta)*2

fig1,ax1 = plt.subplots(1,len(dataset_meta)*2,figsize=(15,5))

for k in range(len(dataset_meta)):
    filename = loom_filepaths[len(subcluster_names)*k]
    dataset_name = raw_data_locations[len(subcluster_names)*k]
    
    with lp.connect(filename,mode='r') as ds:
        S = ds.layers[spliced_layer][:]
        U = ds.layers[unspliced_layer][:]
        gene_names = ds.ra[gene_attr]
        bcs = ds.ca[cell_attr]
        n_cells = S.shape[1]
        monod.preprocess.knee_plot(S+U,ax1[k],viz=True,thr=thr_lb[k])
        cf_ = ((S+U).sum(0)>thr_lb[k])
        
        n_annot_bcs = len(meta['cell_barcode'])
        annot_bcs_in_loom = meta['cell_barcode'].isin(bcs).sum()
        annot_bcs_in_filt_loom = meta['cell_barcode'].isin(bcs[cf_]).sum()
        print(f'Dataset {dataset_name}. \n\t{len(bcs)} barcodes in loom, {cf_.sum()} pass filter. {n_annot_bcs} in annotations; of these, {annot_bcs_in_loom} in loom and {annot_bcs_in_filt_loom} in filtered loom.')
        
        #if k==0:
        for subcluster in subcluster_names:
            annot_bcs = meta[(meta['guide_identity'].isin(subcluster))]['cell_barcode']
            cf.append(np.isin(bcs,annot_bcs) & cf_)
            print(f'\t{subcluster}: {len(annot_bcs)} cells in annotations. {np.isin(bcs,annot_bcs).sum()} in loom. {cf[-1].sum()} pass filter.')



    ax1[k].set_title(dataset_name)
    
# !mkdir ./figs    
fig_dir = './figs/'
fig_string = fig_dir + 'kneeplots_all_norman.png'
fig1.tight_layout()
plt.savefig(fig_string,dpi=450)
# Out:
# Dataset allcrispr.
# 	116844 barcodes in loom, 94649 pass filter. 111445 in annotations; of these, 111445 in loom and 94514 in filtered loom.
# 	['NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0']: 3532 cells in annotations. 3532 in loom. 3255 pass filter.
# 	['NegCtrl1_NegCtrl0__NegCtrl1_NegCtrl0']: 2948 cells in annotations. 2948 in loom. 2679 pass filter.
# 	['NegCtrl11_NegCtrl0__NegCtrl11_NegCtrl0']: 2839 cells in annotations. 2839 in loom. 2622 pass filter.
# 	['NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0']: 2536 cells in annotations. 2536 in loom. 2362 pass filter.
# 	['CEBPE_RUNX1T1__CEBPE_RUNX1T1']: 1219 cells in annotations. 1219 in loom. 1018 pass filter.
# 	['KLF1_NegCtrl0__KLF1_NegCtrl0']: 1197 cells in annotations. 1197 in loom. 1109 pass filter.
# 	['TBX3_TBX2__TBX3_TBX2']: 1167 cells in annotations. 1167 in loom. 1028 pass filter.
# 	['SLC4A1_NegCtrl0__SLC4A1_NegCtrl0']: 1000 cells in annotations. 1000 in loom. 882 pass filter.
# 	['ETS2_CNN1__ETS2_CNN1']: 905 cells in annotations. 905 in loom. 798 pass filter.
# 	['UBASH3B_OSR2__UBASH3B_OSR2']: 796 cells in annotations. 796 in loom. 729 pass filter.
# 	['DUSP9_ETS2__DUSP9_ETS2']: 787 cells in annotations. 787 in loom. 634 pass filter.
# 	['NegCtrl0_BAK1__NegCtrl0_BAK1']: 770 cells in annotations. 770 in loom. 721 pass filter.
# 	['NegCtrl0_KLF1__NegCtrl0_KLF1']: 763 cells in annotations. 763 in loom. 714 pass filter.
# 	['NegCtrl0_ETS2__NegCtrl0_ETS2']: 750 cells in annotations. 750 in loom. 682 pass filter.
# 	['DUSP9_NegCtrl0__DUSP9_NegCtrl0']: 731 cells in annotations. 731 in loom. 579 pass filter.
# 	['BAK1_NegCtrl0__BAK1_NegCtrl0']: 687 cells in annotations. 687 in loom. 630 pass filter.
# 	['SET_KLF1__SET_KLF1']: 667 cells in annotations. 667 in loom. 629 pass filter.
# 	['NegCtrl0_CEBPE__NegCtrl0_CEBPE']: 667 cells in annotations. 667 in loom. 473 pass filter.
# 	['CBL_NegCtrl0__CBL_NegCtrl0']: 663 cells in annotations. 663 in loom. 604 pass filter.
# 	['SET_CEBPE__SET_CEBPE']: 658 cells in annotations. 658 in loom. 571 pass filter.
# 	['SET_NegCtrl0__SET_NegCtrl0']: 655 cells in annotations. 655 in loom. 590 pass filter.
# 	['ZNF318_NegCtrl0__ZNF318_NegCtrl0']: 650 cells in annotations. 650 in loom. 605 pass filter.
# 	['LHX1_ELMSAN1__LHX1_ELMSAN1']: 647 cells in annotations. 647 in loom. 536 pass filter.
# 	['FOSB_NegCtrl0__FOSB_NegCtrl0']: 630 cells in annotations. 630 in loom. 561 pass filter.
# 	['MAML2_NegCtrl0__MAML2_NegCtrl0']: 626 cells in annotations. 626 in loom. 572 pass filter.
# 	['LYL1_IER5L__LYL1_IER5L']: 623 cells in annotations. 623 in loom. 429 pass filter.
# 	['ZC3HAV1_HOXC13__ZC3HAV1_HOXC13']: 618 cells in annotations. 618 in loom. 473 pass filter.
# 	['NegCtrl0_UBASH3B__NegCtrl0_UBASH3B']: 614 cells in annotations. 614 in loom. 565 pass filter.
# 	['UBASH3B_NegCtrl0__UBASH3B_NegCtrl0']: 588 cells in annotations. 588 in loom. 516 pass filter.
# 	['BCL2L11_NegCtrl0__BCL2L11_NegCtrl0']: 582 cells in annotations. 582 in loom. 524 pass filter.
# 	['MAP2K3_ELMSAN1__MAP2K3_ELMSAN1']: 581 cells in annotations. 581 in loom. 546 pass filter.
# 	['MAP2K3_NegCtrl0__MAP2K3_NegCtrl0']: 579 cells in annotations. 579 in loom. 532 pass filter.
# 	['MAP2K3_MAP2K6__MAP2K3_MAP2K6']: 571 cells in annotations. 571 in loom. 536 pass filter.
# 	['CEBPE_NegCtrl0__CEBPE_NegCtrl0']: 566 cells in annotations. 566 in loom. 440 pass filter.
# 	['C19orf26_NegCtrl0__C19orf26_NegCtrl0']: 562 cells in annotations. 562 in loom. 487 pass filter.
# 	['AHR_NegCtrl0__AHR_NegCtrl0']: 558 cells in annotations. 558 in loom. 463 pass filter.
# 	['SLC6A9_NegCtrl0__SLC6A9_NegCtrl0']: 558 cells in annotations. 558 in loom. 507 pass filter.
# 	['UBASH3B_UBASH3A__UBASH3B_UBASH3A']: 554 cells in annotations. 554 in loom. 486 pass filter.
# 	['FOXF1_NegCtrl0__FOXF1_NegCtrl0']: 552 cells in annotations. 552 in loom. 490 pass filter.
# 	['TMSB4X_NegCtrl0__TMSB4X_NegCtrl0']: 543 cells in annotations. 543 in loom. 480 pass filter.
# 	['S1PR2_NegCtrl0__S1PR2_NegCtrl0']: 541 cells in annotations. 541 in loom. 459 pass filter.
# 	['BCORL1_NegCtrl0__BCORL1_NegCtrl0']: 533 cells in annotations. 533 in loom. 469 pass filter.
# 	['NegCtrl0_OSR2__NegCtrl0_OSR2']: 530 cells in annotations. 530 in loom. 452 pass filter.
# 	['ZC3HAV1_NegCtrl0__ZC3HAV1_NegCtrl0']: 516 cells in annotations. 516 in loom. 470 pass filter.
# 	['NegCtrl0_FEV__NegCtrl0_FEV']: 513 cells in annotations. 513 in loom. 417 pass filter.
# 	['NegCtrl0_ELMSAN1__NegCtrl0_ELMSAN1']: 512 cells in annotations. 512 in loom. 475 pass filter.
# 	['MAPK1_PRTG__MAPK1_PRTG']: 500 cells in annotations. 500 in loom. 434 pass filter.
# 	['MAPK1_TGFBR2__MAPK1_TGFBR2']: 497 cells in annotations. 497 in loom. 443 pass filter.
# 	['ARRDC3_NegCtrl0__ARRDC3_NegCtrl0']: 495 cells in annotations. 495 in loom. 435 pass filter.
# 	['FOXA3_NegCtrl0__FOXA3_NegCtrl0']: 494 cells in annotations. 494 in loom. 405 pass filter.
# 	['SGK1_NegCtrl0__SGK1_NegCtrl0']: 483 cells in annotations. 483 in loom. 411 pass filter.
# 	['AHR_KLF1__AHR_KLF1']: 481 cells in annotations. 481 in loom. 440 pass filter.
# 	['NegCtrl0_CNN1__NegCtrl0_CNN1']: 480 cells in annotations. 480 in loom. 424 pass filter.
# 	['FOXA1_NegCtrl0__FOXA1_NegCtrl0']: 479 cells in annotations. 479 in loom. 414 pass filter.
# 	['CSRNP1_NegCtrl0__CSRNP1_NegCtrl0']: 478 cells in annotations. 478 in loom. 447 pass filter.
# 	['CELF2_NegCtrl0__CELF2_NegCtrl0']: 475 cells in annotations. 475 in loom. 425 pass filter.
# 	['OSR2_NegCtrl0__OSR2_NegCtrl0']: 473 cells in annotations. 473 in loom. 404 pass filter.
# 	['CNNM4_NegCtrl0__CNNM4_NegCtrl0']: 470 cells in annotations. 470 in loom. 427 pass filter.
# 	['CEBPE_KLF1__CEBPE_KLF1']: 468 cells in annotations. 468 in loom. 422 pass filter.
# 	['BPGM_NegCtrl0__BPGM_NegCtrl0']: 464 cells in annotations. 464 in loom. 411 pass filter.
# 	['NegCtrl0_MEIS1__NegCtrl0_MEIS1']: 463 cells in annotations. 463 in loom. 409 pass filter.
# 	['GLB1L2_NegCtrl0__GLB1L2_NegCtrl0']: 463 cells in annotations. 463 in loom. 419 pass filter.
# 	['BCL2L11_TGFBR2__BCL2L11_TGFBR2']: 463 cells in annotations. 463 in loom. 415 pass filter.
# 	['ETS2_MAPK1__ETS2_MAPK1']: 459 cells in annotations. 459 in loom. 321 pass filter.
# 	['MAP2K6_ELMSAN1__MAP2K6_ELMSAN1']: 451 cells in annotations. 451 in loom. 422 pass filter.
# 	['ETS2_NegCtrl0__ETS2_NegCtrl0']: 451 cells in annotations. 451 in loom. 403 pass filter.
# 	['UBASH3A_NegCtrl0__UBASH3A_NegCtrl0']: 450 cells in annotations. 450 in loom. 405 pass filter.
# 	['NegCtrl0_MAPK1__NegCtrl0_MAPK1']: 446 cells in annotations. 446 in loom. 395 pass filter.
# 	['NegCtrl0_RUNX1T1__NegCtrl0_RUNX1T1']: 446 cells in annotations. 446 in loom. 409 pass filter.
# 	['IKZF3_NegCtrl0__IKZF3_NegCtrl0']: 445 cells in annotations. 445 in loom. 340 pass filter.
# 	['ETS2_IKZF3__ETS2_IKZF3']: 445 cells in annotations. 445 in loom. 333 pass filter.
# 	['ETS2_PRTG__ETS2_PRTG']: 445 cells in annotations. 445 in loom. 389 pass filter.
# 	['MAP2K6_NegCtrl0__MAP2K6_NegCtrl0']: 444 cells in annotations. 444 in loom. 419 pass filter.
# 	['IRF1_SET__IRF1_SET']: 444 cells in annotations. 444 in loom. 379 pass filter.
# 	['TSC22D1_NegCtrl0__TSC22D1_NegCtrl0']: 441 cells in annotations. 441 in loom. 403 pass filter.
# 	['ETS2_IGDCC3__ETS2_IGDCC3']: 441 cells in annotations. 441 in loom. 394 pass filter.
# 	['NegCtrl0_MAP2K6__NegCtrl0_MAP2K6']: 434 cells in annotations. 434 in loom. 392 pass filter.
# 	['LYL1_NegCtrl0__LYL1_NegCtrl0']: 432 cells in annotations. 432 in loom. 394 pass filter.
# 	['IRF1_NegCtrl0__IRF1_NegCtrl0']: 427 cells in annotations. 427 in loom. 389 pass filter.
# 	['FOSB_UBASH3B__FOSB_UBASH3B']: 426 cells in annotations. 426 in loom. 377 pass filter.
# 	['ZBTB25_NegCtrl0__ZBTB25_NegCtrl0']: 426 cells in annotations. 426 in loom. 392 pass filter.
# 	['ELMSAN1_NegCtrl0__ELMSAN1_NegCtrl0']: 425 cells in annotations. 425 in loom. 394 pass filter.
# 	['PTPN1_NegCtrl0__PTPN1_NegCtrl0']: 419 cells in annotations. 419 in loom. 372 pass filter.
# 	['CEBPE_PTPN12__CEBPE_PTPN12']: 415 cells in annotations. 415 in loom. 357 pass filter.
# 	['CEBPB_MAPK1__CEBPB_MAPK1']: 412 cells in annotations. 412 in loom. 338 pass filter.
# 	['NegCtrl0_MAP7D1__NegCtrl0_MAP7D1']: 412 cells in annotations. 412 in loom. 372 pass filter.
# 	['HOXB9_NegCtrl0__HOXB9_NegCtrl0']: 410 cells in annotations. 410 in loom. 334 pass filter.
# 	['CBL_UBASH3B__CBL_UBASH3B']: 410 cells in annotations. 410 in loom. 306 pass filter.
# 	['ZC3HAV1_CEBPE__ZC3HAV1_CEBPE']: 410 cells in annotations. 410 in loom. 386 pass filter.
# 	['NegCtrl0_SPI1__NegCtrl0_SPI1']: 403 cells in annotations. 403 in loom. 301 pass filter.
# 	['UBASH3B_CNN1__UBASH3B_CNN1']: 402 cells in annotations. 402 in loom. 292 pass filter.
# 	['NegCtrl0_TGFBR2__NegCtrl0_TGFBR2']: 401 cells in annotations. 401 in loom. 362 pass filter.
# 	['CNN1_MAPK1__CNN1_MAPK1']: 398 cells in annotations. 398 in loom. 329 pass filter.
# 	['KLF1_BAK1__KLF1_BAK1']: 395 cells in annotations. 395 in loom. 360 pass filter.
# 	['DLX2_NegCtrl0__DLX2_NegCtrl0']: 387 cells in annotations. 387 in loom. 333 pass filter.
# 	['FOSB_OSR2__FOSB_OSR2']: 382 cells in annotations. 382 in loom. 318 pass filter.
# 	['DUSP9_IGDCC3__DUSP9_IGDCC3']: 382 cells in annotations. 382 in loom. 286 pass filter.
# 	['ATL1_NegCtrl0__ATL1_NegCtrl0']: 379 cells in annotations. 379 in loom. 288 pass filter.
# 	['LHX1_NegCtrl0__LHX1_NegCtrl0']: 375 cells in annotations. 375 in loom. 306 pass filter.
# 	['NegCtrl0_FOXA1__NegCtrl0_FOXA1']: 372 cells in annotations. 372 in loom. 314 pass filter.
# 	['TBX3_NegCtrl0__TBX3_NegCtrl0']: 369 cells in annotations. 369 in loom. 334 pass filter.
# 	['NegCtrl0_UBASH3A__NegCtrl0_UBASH3A']: 369 cells in annotations. 369 in loom. 328 pass filter.
# 	['FOXL2_NegCtrl0__FOXL2_NegCtrl0']: 368 cells in annotations. 368 in loom. 291 pass filter.
# 	['IGDCC3_MAPK1__IGDCC3_MAPK1']: 368 cells in annotations. 368 in loom. 311 pass filter.
# 	['MAP4K5_NegCtrl0__MAP4K5_NegCtrl0']: 366 cells in annotations. 366 in loom. 329 pass filter.
# 	['DUSP9_KLF1__DUSP9_KLF1']: 366 cells in annotations. 366 in loom. 312 pass filter.
# 	['CBFA2T3_NegCtrl0__CBFA2T3_NegCtrl0']: 365 cells in annotations. 365 in loom. 319 pass filter.
# 	['PTPN12_PTPN9__PTPN12_PTPN9']: 364 cells in annotations. 364 in loom. 287 pass filter.
# 	['CDKN1B_NegCtrl0__CDKN1B_NegCtrl0']: 364 cells in annotations. 364 in loom. 332 pass filter.
# 	['MAP4K3_NegCtrl0__MAP4K3_NegCtrl0']: 363 cells in annotations. 363 in loom. 331 pass filter.
# 	['ZBTB1_NegCtrl0__ZBTB1_NegCtrl0']: 362 cells in annotations. 362 in loom. 318 pass filter.
# 	['KLF1_FOXA1__KLF1_FOXA1']: 361 cells in annotations. 361 in loom. 316 pass filter.
# 	['POU3F2_NegCtrl0__POU3F2_NegCtrl0']: 359 cells in annotations. 359 in loom. 292 pass filter.
# 	['BPGM_ZBTB1__BPGM_ZBTB1']: 358 cells in annotations. 358 in loom. 303 pass filter.
# 	['SGK1_S1PR2__SGK1_S1PR2']: 358 cells in annotations. 358 in loom. 272 pass filter.
# 	['CLDN6_NegCtrl0__CLDN6_NegCtrl0']: 355 cells in annotations. 355 in loom. 306 pass filter.
# 	['ETS2_CEBPE__ETS2_CEBPE']: 354 cells in annotations. 354 in loom. 291 pass filter.
# 	['SAMD1_PTPN12__SAMD1_PTPN12']: 351 cells in annotations. 351 in loom. 250 pass filter.
# 	['IGDCC3_NegCtrl0__IGDCC3_NegCtrl0']: 349 cells in annotations. 349 in loom. 306 pass filter.
# 	['SGK1_TBX2__SGK1_TBX2']: 349 cells in annotations. 349 in loom. 291 pass filter.
# 	['NegCtrl0_TBX2__NegCtrl0_TBX2']: 349 cells in annotations. 349 in loom. 308 pass filter.
# 	['NegCtrl0_PRTG__NegCtrl0_PRTG']: 349 cells in annotations. 349 in loom. 301 pass filter.
# 	['CBL_CNN1__CBL_CNN1']: 348 cells in annotations. 348 in loom. 246 pass filter.
# 	['FOSB_PTPN12__FOSB_PTPN12']: 345 cells in annotations. 345 in loom. 315 pass filter.
# 	['NegCtrl0_DLX2__NegCtrl0_DLX2']: 345 cells in annotations. 345 in loom. 292 pass filter.
# 	['TBX2_NegCtrl0__TBX2_NegCtrl0']: 341 cells in annotations. 341 in loom. 316 pass filter.
# 	['PTPN12_OSR2__PTPN12_OSR2']: 339 cells in annotations. 339 in loom. 314 pass filter.
# 	['MAP7D1_NegCtrl0__MAP7D1_NegCtrl0']: 339 cells in annotations. 339 in loom. 299 pass filter.
# 	['MAP2K3_SLC38A2__MAP2K3_SLC38A2']: 338 cells in annotations. 338 in loom. 318 pass filter.
# 	['KLF1_TGFBR2__KLF1_TGFBR2']: 337 cells in annotations. 337 in loom. 298 pass filter.
# 	['PRTG_NegCtrl0__PRTG_NegCtrl0']: 336 cells in annotations. 336 in loom. 299 pass filter.
# 	['CBL_PTPN12__CBL_PTPN12']: 335 cells in annotations. 335 in loom. 273 pass filter.
# 	['RUNX1T1_NegCtrl0__RUNX1T1_NegCtrl0']: 333 cells in annotations. 333 in loom. 314 pass filter.
# 	['NegCtrl0_SLC38A2__NegCtrl0_SLC38A2']: 332 cells in annotations. 332 in loom. 298 pass filter.
# 	['CEBPB_PTPN12__CEBPB_PTPN12']: 331 cells in annotations. 331 in loom. 276 pass filter.
# 	['RREB1_NegCtrl0__RREB1_NegCtrl0']: 331 cells in annotations. 331 in loom. 275 pass filter.
# 	['NegCtrl0_SET__NegCtrl0_SET']: 331 cells in annotations. 331 in loom. 284 pass filter.
# 	['NegCtrl0_ZBTB1__NegCtrl0_ZBTB1']: 331 cells in annotations. 331 in loom. 287 pass filter.
# 	['KIF2C_NegCtrl0__KIF2C_NegCtrl0']: 329 cells in annotations. 329 in loom. 283 pass filter.
# 	['COL2A1_NegCtrl0__COL2A1_NegCtrl0']: 329 cells in annotations. 329 in loom. 297 pass filter.
# 	['FOXA3_HOXB9__FOXA3_HOXB9']: 329 cells in annotations. 329 in loom. 204 pass filter.
# 	['TMSB4X_BAK1__TMSB4X_BAK1']: 329 cells in annotations. 329 in loom. 295 pass filter.
# 	['COL1A1_NegCtrl0__COL1A1_NegCtrl0']: 328 cells in annotations. 328 in loom. 262 pass filter.
# 	['RHOXF2_NegCtrl0__RHOXF2_NegCtrl0']: 328 cells in annotations. 328 in loom. 245 pass filter.
# 	['ISL2_NegCtrl0__ISL2_NegCtrl0']: 327 cells in annotations. 327 in loom. 296 pass filter.
# 	['TGFBR2_C19orf26__TGFBR2_C19orf26']: 325 cells in annotations. 325 in loom. 269 pass filter.
# 	['UBASH3B_PTPN9__UBASH3B_PTPN9']: 325 cells in annotations. 325 in loom. 281 pass filter.
# 	['ETS2_MAP7D1__ETS2_MAP7D1']: 324 cells in annotations. 324 in loom. 270 pass filter.
# 	['NegCtrl0_TBX3__NegCtrl0_TBX3']: 322 cells in annotations. 322 in loom. 286 pass filter.
# 	['NegCtrl0_FOXF1__NegCtrl0_FOXF1']: 322 cells in annotations. 322 in loom. 293 pass filter.
# 	['EGR1_NegCtrl0__EGR1_NegCtrl0']: 322 cells in annotations. 322 in loom. 285 pass filter.
# 	['RHOXF2_SET__RHOXF2_SET']: 321 cells in annotations. 321 in loom. 227 pass filter.
# 	['MAPK1_NegCtrl0__MAPK1_NegCtrl0']: 319 cells in annotations. 319 in loom. 276 pass filter.
# 	['TGFBR2_ETS2__TGFBR2_ETS2']: 318 cells in annotations. 318 in loom. 290 pass filter.
# 	['NegCtrl0_CLDN6__NegCtrl0_CLDN6']: 315 cells in annotations. 315 in loom. 266 pass filter.
# 	['NegCtrl0_ZBTB25__NegCtrl0_ZBTB25']: 314 cells in annotations. 314 in loom. 287 pass filter.
# 	['MEIS1_NegCtrl0__MEIS1_NegCtrl0']: 313 cells in annotations. 313 in loom. 272 pass filter.
# 	['PTPN12_UBASH3A__PTPN12_UBASH3A']: 311 cells in annotations. 311 in loom. 233 pass filter.
# 	['KLF1_CEBPA__KLF1_CEBPA']: 311 cells in annotations. 311 in loom. 198 pass filter.
# 	['NegCtrl0_C19orf26__NegCtrl0_C19orf26']: 310 cells in annotations. 310 in loom. 285 pass filter.
# 	['POU3F2_FOXL2__POU3F2_FOXL2']: 309 cells in annotations. 309 in loom. 168 pass filter.
# 	['CBL_PTPN9__CBL_PTPN9']: 306 cells in annotations. 306 in loom. 243 pass filter.
# 	['NegCtrl0_KIF2C__NegCtrl0_KIF2C']: 305 cells in annotations. 305 in loom. 278 pass filter.
# 	['PTPN12_ZBTB25__PTPN12_ZBTB25']: 303 cells in annotations. 303 in loom. 240 pass filter.
# 	['HK2_NegCtrl0__HK2_NegCtrl0']: 303 cells in annotations. 303 in loom. 258 pass filter.
# 	['MAPK1_IKZF3__MAPK1_IKZF3']: 302 cells in annotations. 302 in loom. 241 pass filter.
# 	['MAP2K6_SPI1__MAP2K6_SPI1']: 302 cells in annotations. 302 in loom. 276 pass filter.
# 	['BPGM_SAMD1__BPGM_SAMD1']: 301 cells in annotations. 301 in loom. 239 pass filter.
# 	['MAP2K6_IKZF3__MAP2K6_IKZF3']: 300 cells in annotations. 300 in loom. 251 pass filter.
# 	['SGK1_TBX3__SGK1_TBX3']: 300 cells in annotations. 300 in loom. 260 pass filter.
# 	['SNAI1_UBASH3B__SNAI1_UBASH3B']: 299 cells in annotations. 299 in loom. 259 pass filter.
# 	['MIDN_NegCtrl0__MIDN_NegCtrl0']: 298 cells in annotations. 298 in loom. 221 pass filter.
# 	['UBASH3B_PTPN12__UBASH3B_PTPN12']: 298 cells in annotations. 298 in loom. 233 pass filter.
# 	['KLF1_COL2A1__KLF1_COL2A1']: 298 cells in annotations. 298 in loom. 272 pass filter.
# 	['DUSP9_PRTG__DUSP9_PRTG']: 297 cells in annotations. 297 in loom. 238 pass filter.
# 	['PRDM1_NegCtrl0__PRDM1_NegCtrl0']: 297 cells in annotations. 297 in loom. 198 pass filter.
# 	['FOXA1_HOXB9__FOXA1_HOXB9']: 295 cells in annotations. 295 in loom. 193 pass filter.
# 	['NegCtrl0_CBFA2T3__NegCtrl0_CBFA2T3']: 293 cells in annotations. 293 in loom. 265 pass filter.
# 	['NegCtrl0_HOXB9__NegCtrl0_HOXB9']: 291 cells in annotations. 291 in loom. 235 pass filter.
# 	['DUSP9_MAPK1__DUSP9_MAPK1']: 290 cells in annotations. 290 in loom. 260 pass filter.
# 	['CEBPB_NegCtrl0__CEBPB_NegCtrl0']: 286 cells in annotations. 286 in loom. 211 pass filter.
# 	['CNN1_NegCtrl0__CNN1_NegCtrl0']: 285 cells in annotations. 285 in loom. 251 pass filter.
# 	['FEV_ISL2__FEV_ISL2']: 284 cells in annotations. 284 in loom. 153 pass filter.
# 	['NegCtrl0_FOXL2__NegCtrl0_FOXL2']: 284 cells in annotations. 284 in loom. 227 pass filter.
# 	['PTPN12_SNAI1__PTPN12_SNAI1']: 283 cells in annotations. 283 in loom. 244 pass filter.
# 	['SAMD1_NegCtrl0__SAMD1_NegCtrl0']: 281 cells in annotations. 281 in loom. 210 pass filter.
# 	['KIAA1804_NegCtrl0__KIAA1804_NegCtrl0']: 278 cells in annotations. 278 in loom. 250 pass filter.
# 	['FEV_MAP7D1__FEV_MAP7D1']: 277 cells in annotations. 277 in loom. 193 pass filter.
# 	['AHR_FEV__AHR_FEV']: 276 cells in annotations. 276 in loom. 140 pass filter.
# 	['HOXA13_NegCtrl0__HOXA13_NegCtrl0']: 274 cells in annotations. 274 in loom. 173 pass filter.
# 	['FOXA1_FOXF1__FOXA1_FOXF1']: 272 cells in annotations. 272 in loom. 213 pass filter.
# 	['PTPN13_NegCtrl0__PTPN13_NegCtrl0']: 270 cells in annotations. 270 in loom. 237 pass filter.
# 	['NegCtrl0_COL2A1__NegCtrl0_COL2A1']: 269 cells in annotations. 269 in loom. 239 pass filter.
# 	['SNAI1_NegCtrl0__SNAI1_NegCtrl0']: 267 cells in annotations. 267 in loom. 235 pass filter.
# 	['JUN_NegCtrl0__JUN_NegCtrl0']: 266 cells in annotations. 266 in loom. 212 pass filter.
# 	['TGFBR2_PRTG__TGFBR2_PRTG']: 265 cells in annotations. 265 in loom. 222 pass filter.
# 	['ZBTB10_PTPN12__ZBTB10_PTPN12']: 265 cells in annotations. 265 in loom. 175 pass filter.
# 	['C3orf72_NegCtrl0__C3orf72_NegCtrl0']: 264 cells in annotations. 264 in loom. 204 pass filter.
# 	['NegCtrl0_IGDCC3__NegCtrl0_IGDCC3']: 264 cells in annotations. 264 in loom. 243 pass filter.
# 	['RHOXF2_ZBTB25__RHOXF2_ZBTB25']: 263 cells in annotations. 263 in loom. 197 pass filter.
# 	['KLF1_MAP2K6__KLF1_MAP2K6']: 263 cells in annotations. 263 in loom. 236 pass filter.
# 	['MAP2K3_IKZF3__MAP2K3_IKZF3']: 261 cells in annotations. 261 in loom. 221 pass filter.
# 	['NegCtrl0_ISL2__NegCtrl0_ISL2']: 255 cells in annotations. 255 in loom. 235 pass filter.
# 	['UBASH3B_ZBTB25__UBASH3B_ZBTB25']: 255 cells in annotations. 255 in loom. 212 pass filter.
# 	['KIF18B_NegCtrl0__KIF18B_NegCtrl0']: 254 cells in annotations. 254 in loom. 231 pass filter.
# 	['TP73_NegCtrl0__TP73_NegCtrl0']: 248 cells in annotations. 248 in loom. 155 pass filter.
# 	['FOSB_IKZF3__FOSB_IKZF3']: 247 cells in annotations. 247 in loom. 200 pass filter.
# 	['ZNF318_FOXL2__ZNF318_FOXL2']: 246 cells in annotations. 246 in loom. 209 pass filter.
# 	['TGFBR2_NegCtrl0__TGFBR2_NegCtrl0']: 245 cells in annotations. 245 in loom. 226 pass filter.
# 	['NegCtrl0_PTPN9__NegCtrl0_PTPN9']: 245 cells in annotations. 245 in loom. 222 pass filter.
# 	['CEBPA_NegCtrl0__CEBPA_NegCtrl0']: 245 cells in annotations. 245 in loom. 97 pass filter.
# 	['KMT2A_NegCtrl0__KMT2A_NegCtrl0']: 241 cells in annotations. 241 in loom. 213 pass filter.
# 	['CKS1B_NegCtrl0__CKS1B_NegCtrl0']: 241 cells in annotations. 241 in loom. 196 pass filter.
# 	['SAMD1_UBASH3B__SAMD1_UBASH3B']: 240 cells in annotations. 240 in loom. 172 pass filter.
# 	['CEBPE_CNN1__CEBPE_CNN1']: 237 cells in annotations. 237 in loom. 190 pass filter.
# 	['HNF4A_NegCtrl0__HNF4A_NegCtrl0']: 237 cells in annotations. 237 in loom. 203 pass filter.
# 	['NCL_NegCtrl0__NCL_NegCtrl0']: 237 cells in annotations. 237 in loom. 197 pass filter.
# 	['KLF1_CLDN6__KLF1_CLDN6']: 237 cells in annotations. 237 in loom. 196 pass filter.
# 	['NegCtrl0_IKZF3__NegCtrl0_IKZF3']: 236 cells in annotations. 236 in loom. 168 pass filter.
# 	['PTPN12_NegCtrl0__PTPN12_NegCtrl0']: 234 cells in annotations. 234 in loom. 220 pass filter.
# 	['ARID1A_NegCtrl0__ARID1A_NegCtrl0']: 232 cells in annotations. 232 in loom. 167 pass filter.
# 	['CDKN1C_NegCtrl0__CDKN1C_NegCtrl0']: 230 cells in annotations. 230 in loom. 208 pass filter.
# 	['NegCtrl0_IER5L__NegCtrl0_IER5L']: 222 cells in annotations. 222 in loom. 180 pass filter.
# 	['NegCtrl0_HOXC13__NegCtrl0_HOXC13']: 218 cells in annotations. 218 in loom. 145 pass filter.
# 	['NegCtrl0_SAMD1__NegCtrl0_SAMD1']: 217 cells in annotations. 217 in loom. 171 pass filter.
# 	['FOXA3_FOXA1__FOXA3_FOXA1']: 216 cells in annotations. 216 in loom. 170 pass filter.
# 	['POU3F2_CBFA2T3__POU3F2_CBFA2T3']: 216 cells in annotations. 216 in loom. 158 pass filter.
# 	['NegCtrl0_CEBPA__NegCtrl0_CEBPA']: 215 cells in annotations. 215 in loom. 106 pass filter.
# 	['FOXO4_NegCtrl0__FOXO4_NegCtrl0']: 215 cells in annotations. 215 in loom. 190 pass filter.
# 	['CITED1_NegCtrl0__CITED1_NegCtrl0']: 215 cells in annotations. 215 in loom. 180 pass filter.
# 	['NegCtrl0_PTPN12__NegCtrl0_PTPN12']: 211 cells in annotations. 211 in loom. 184 pass filter.
# 	['CEBPB_OSR2__CEBPB_OSR2']: 211 cells in annotations. 211 in loom. 144 pass filter.
# 	['SPI1_NegCtrl0__SPI1_NegCtrl0']: 210 cells in annotations. 210 in loom. 148 pass filter.
# 	['NegCtrl0_CEBPB__NegCtrl0_CEBPB']: 202 cells in annotations. 202 in loom. 153 pass filter.
# 	['PTPN9_NegCtrl0__PTPN9_NegCtrl0']: 200 cells in annotations. 200 in loom. 184 pass filter.
# 	['NegCtrl0_SNAI1__NegCtrl0_SNAI1']: 200 cells in annotations. 200 in loom. 171 pass filter.
# 	['FOXF1_HOXB9__FOXF1_HOXB9']: 200 cells in annotations. 200 in loom. 145 pass filter.
# 	['FOXL2_MEIS1__FOXL2_MEIS1']: 193 cells in annotations. 193 in loom. 123 pass filter.
# 	['LYL1_CEBPB__LYL1_CEBPB']: 192 cells in annotations. 192 in loom. 161 pass filter.
# 	['FOXA1_FOXL2__FOXA1_FOXL2']: 192 cells in annotations. 192 in loom. 123 pass filter.
# 	['FOXF1_FOXL2__FOXF1_FOXL2']: 192 cells in annotations. 192 in loom. 116 pass filter.
# 	['NIT1_NegCtrl0__NIT1_NegCtrl0']: 192 cells in annotations. 192 in loom. 147 pass filter.
# 	['FEV_NegCtrl0__FEV_NegCtrl0']: 191 cells in annotations. 191 in loom. 153 pass filter.
# 	['SAMD1_ZBTB1__SAMD1_ZBTB1']: 191 cells in annotations. 191 in loom. 141 pass filter.
# 	['CBL_TGFBR2__CBL_TGFBR2']: 188 cells in annotations. 188 in loom. 169 pass filter.
# 	['NegCtrl0_CDKN1B__NegCtrl0_CDKN1B']: 186 cells in annotations. 186 in loom. 167 pass filter.
# 	['CDKN1A_NegCtrl0__CDKN1A_NegCtrl0']: 184 cells in annotations. 184 in loom. 168 pass filter.
# 	['IER5L_NegCtrl0__IER5L_NegCtrl0']: 183 cells in annotations. 183 in loom. 170 pass filter.
# 	['DUSP9_SNAI1__DUSP9_SNAI1']: 183 cells in annotations. 183 in loom. 92 pass filter.
# 	['ZBTB10_ELMSAN1__ZBTB10_ELMSAN1']: 182 cells in annotations. 182 in loom. 125 pass filter.
# 	['CEBPE_CEBPA__CEBPE_CEBPA']: 180 cells in annotations. 180 in loom. 86 pass filter.
# 	['CEBPE_SPI1__CEBPE_SPI1']: 179 cells in annotations. 179 in loom. 81 pass filter.
# 	['CNN1_UBASH3A__CNN1_UBASH3A']: 178 cells in annotations. 178 in loom. 120 pass filter.
# 	['NegCtrl0_CDKN1A__NegCtrl0_CDKN1A']: 176 cells in annotations. 176 in loom. 162 pass filter.
# 	['FOXA3_FOXF1__FOXA3_FOXF1']: 175 cells in annotations. 175 in loom. 120 pass filter.
# 	['BCL2L11_BAK1__BCL2L11_BAK1']: 175 cells in annotations. 175 in loom. 159 pass filter.
# 	['TGFBR2_IGDCC3__TGFBR2_IGDCC3_1']: 165 cells in annotations. 165 in loom. 136 pass filter.
# 	['NegCtrl0_STIL__NegCtrl0_STIL']: 164 cells in annotations. 164 in loom. 133 pass filter.
# 	['FEV_CBFA2T3__FEV_CBFA2T3']: 159 cells in annotations. 159 in loom. 48 pass filter.
# 	['FOSB_CEBPE__FOSB_CEBPE']: 151 cells in annotations. 151 in loom. 86 pass filter.
# 	['STIL_NegCtrl0__STIL_NegCtrl0']: 145 cells in annotations. 145 in loom. 121 pass filter.
# 	['IGDCC3_ZBTB25__IGDCC3_ZBTB25']: 141 cells in annotations. 141 in loom. 127 pass filter.
# 	['IGDCC3_PRTG__IGDCC3_PRTG']: 140 cells in annotations. 140 in loom. 121 pass filter.
# 	['TGFBR2_IGDCC3__TGFBR2_IGDCC3_2']: 136 cells in annotations. 136 in loom. 118 pass filter.
# 	['CDKN1B_CDKN1A__CDKN1B_CDKN1A']: 134 cells in annotations. 134 in loom. 122 pass filter.
# 	['SNAI1_DLX2__SNAI1_DLX2']: 131 cells in annotations. 131 in loom. 93 pass filter.
# 	['FOXA3_FOXL2__FOXA3_FOXL2']: 130 cells in annotations. 130 in loom. 80 pass filter.
# 	['HES7_NegCtrl0__HES7_NegCtrl0']: 126 cells in annotations. 126 in loom. 66 pass filter.
# 	['CDKN1C_CDKN1A__CDKN1C_CDKN1A']: 126 cells in annotations. 126 in loom. 113 pass filter.
# 	['CEBPE_CEBPB__CEBPE_CEBPB']: 114 cells in annotations. 114 in loom. 66 pass filter.
# 	['PLK4_NegCtrl0__PLK4_NegCtrl0']: 113 cells in annotations. 113 in loom. 92 pass filter.
# 	['CDKN1C_CDKN1B__CDKN1C_CDKN1B']: 107 cells in annotations. 107 in loom. 97 pass filter.
# 	['PRDM1_CBFA2T3__PRDM1_CBFA2T3']: 106 cells in annotations. 106 in loom. 40 pass filter.
# 	['ZBTB10_SNAI1__ZBTB10_SNAI1']: 100 cells in annotations. 100 in loom. 42 pass filter.
# 	['KIF18B_KIF2C__KIF18B_KIF2C']: 96 cells in annotations. 96 in loom. 71 pass filter.
# 	['FOXL2_HOXB9__FOXL2_HOXB9']: 96 cells in annotations. 96 in loom. 52 pass filter.
# 	['HOXC13_NegCtrl0__HOXC13_NegCtrl0_2']: 91 cells in annotations. 91 in loom. 54 pass filter.
# 	['ZBTB10_DLX2__ZBTB10_DLX2']: 89 cells in annotations. 89 in loom. 42 pass filter.
# 	['ZC3HAV1_CEBPA__ZC3HAV1_CEBPA']: 86 cells in annotations. 86 in loom. 50 pass filter.
# 	['ZBTB10_NegCtrl0__ZBTB10_NegCtrl0_1']: 86 cells in annotations. 86 in loom. 57 pass filter.
# 	['PLK4_STIL__PLK4_STIL']: 81 cells in annotations. 81 in loom. 68 pass filter.
# 	['HOXC13_NegCtrl0__HOXC13_NegCtrl0_1']: 76 cells in annotations. 76 in loom. 50 pass filter.
# 	['ZBTB10_NegCtrl0__ZBTB10_NegCtrl0_2']: 76 cells in annotations. 76 in loom. 48 pass filter.
# 	['SAMD1_TGFBR2__SAMD1_TGFBR2']: 72 cells in annotations. 72 in loom. 58 pass filter.
# 	['FOSB_CEBPB__FOSB_CEBPB']: 71 cells in annotations. 71 in loom. 40 pass filter.
# 	['CBL_UBASH3A__CBL_UBASH3A']: 64 cells in annotations. 64 in loom. 49 pass filter.
# 	['CEBPB_CEBPA__CEBPB_CEBPA']: 64 cells in annotations. 64 in loom. 27 pass filter.
# 	['C3orf72_FOXL2__C3orf72_FOXL2']: 59 cells in annotations. 59 in loom. 38 pass filter.
# 	['JUN_CEBPB__JUN_CEBPB']: 59 cells in annotations. 59 in loom. 28 pass filter.
# 	['JUN_CEBPA__JUN_CEBPA']: 54 cells in annotations. 54 in loom. 18 pass filter.
# mkdir: cannot create directory ‘./figs’: File exists

# %%
np.mean(np.sum(U+S,axis=0))
# Out:
# 15591.031845879977

# %%
np.mean(np.sum((U+S)>0,axis=0))
# Out:
# 4196.596393481907

# %%
#Conditions with too few cells after filtering
ok = []
okinds = []
for i in range(len(subcluster_names)):
    x = cf[i]
    if x.sum() > 50:
        ok += [subcluster_names[i]]
        okinds += [i]
print(len(ok))
# Out:
# 277

# %%
#re-filter
dataset_meta = ['allcrispr']
print('dataset_meta: ', dataset_meta)
print()

subcluster_names = [i for i in ok]

sub_names_only = ['_'.join(n) for n in subcluster_names]

cluster_names = []
dataset_names = ['norman_'+dataset_meta[0]+'_'+y  for y in sub_names_only]   #To save
print('dataset_names: ', dataset_names)
print('len(dataset_names): ',len(dataset_names))
print()

raw_data_locations = [dataset_meta[0] for y in sub_names_only]
transcriptome_filepath = './gg_200525_genome_polyA_cum_3'

spliced_layer = 'spliced'
unspliced_layer = 'unspliced'
gene_attr = 'gene_name'
cell_attr = 'barcode'

attribute_names=[(unspliced_layer,spliced_layer),gene_attr,cell_attr]

loom_filepaths = ['./'+x+'.loom' for x in raw_data_locations] 
print('loom_filepaths: ',loom_filepaths)

n_datasets = len(loom_filepaths)

cf = np.array(cf)[okinds]
# Out:
# dataset_meta:  ['allcrispr']
#
# dataset_names:  ['norman_allcrispr_NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0', 'norman_allcrispr_NegCtrl1_NegCtrl0__NegCtrl1_NegCtrl0', 'norman_allcrispr_NegCtrl11_NegCtrl0__NegCtrl11_NegCtrl0', 'norman_allcrispr_NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0', 'norman_allcrispr_CEBPE_RUNX1T1__CEBPE_RUNX1T1', 'norman_allcrispr_KLF1_NegCtrl0__KLF1_NegCtrl0', 'norman_allcrispr_TBX3_TBX2__TBX3_TBX2', 'norman_allcrispr_SLC4A1_NegCtrl0__SLC4A1_NegCtrl0', 'norman_allcrispr_ETS2_CNN1__ETS2_CNN1', 'norman_allcrispr_UBASH3B_OSR2__UBASH3B_OSR2', 'norman_allcrispr_DUSP9_ETS2__DUSP9_ETS2', 'norman_allcrispr_NegCtrl0_BAK1__NegCt
l0_CNN1', 'norman_allcrispr_FOXA1_NegCtrl0__FOXA1_NegCtrl0', 'norman_allcrispr_CSRNP1_NegCtrl0__CSRNP1_NegCtrl0', 'norman_allcrispr_CELF2_NegCtrl0__CELF2_NegCtrl0', 'norman_allcrispr_OSR2_NegCtrl0__OSR2_NegCtrl0', 'norman_allcrispr_CNNM4_NegCtrl0__CNNM4_NegCtrl0', 'norman_allcrispr_CEBPE_KLF1__CEBPE_KLF1', 'norman_allcrispr_BPGM_NegCtrl0__BPGM_NegCtrl0', 'norman_allcrispr_NegCtrl0_MEIS1__NegCtrl0_MEIS1', 'norman_allcrispr_GLB1L2_NegCtrl0__GLB1L2_NegCtrl0', 'norman_allcrispr_BCL2L11_TGFBR2__BCL2L11_TGFBR2', 'norman_allcrispr_ETS2_MAPK1__ETS2_MAPK1', 'norman_allcrispr_MAP2K6_ELMSAN1__MAP2K6_ELMSAN1', 'norman_allcrispr_ETS2_NegCtrl0__ETS2_NegCtrl0', 'norman_allcrispr_UBASH3A_NegCtrl0__UBASH3A_NegCtrl0', 'norman_allcrispr_NegCtrl0_MAPK1__NegCtrl0_MAPK1', 'norman_allcrispr_NegCtrl0_RUNX1T1__NegCtrl0_RUNX1T1', 'norman_allcrispr_IKZF3_NegCtrl0__IKZF3_NegCtrl0', 'norman_allcrispr_ETS2_IKZF3__ETS2_IKZF3', 'norman_allcrispr_ETS2_PRTG__ETS2_PRTG', 'norman_allcrispr_MAP2K6_NegCtrl0__MAP2K6_NegCtrl0', 'norman_allcrispr_IRF1_SET__IRF1_SET', 'norman_allcrispr_TSC22D1_NegCtrl0__TSC22D1_NegCtrl0', 'norman_allcrispr_ETS2_IGDCC3__ETS2_IGDCC3', 'norman_allcrispr_NegCtrl0_MAP2K6__NegCtrl0_MAP2K6', 'norman_allcrispr_LYL1_NegCtrl0__LYL1_NegCtrl0', 'norman_allcrispr_IRF1_NegCtrl0__IRF1_NegCtrl0', 'norman_allcrispr_FOSB_UBASH3B__FOSB_UBASH3B', 'norman ...
# len(dataset_names):  277
#
# loom_filepaths:  ['/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr.loom', '/home/tchari/counts/norman_crispr/loom/allcrispr ...

# %%
#final list of selected barcodes in each condition
cf = list(cf)

# %% [markdown]
# ## **Gene Filtering**
#
# Select moderately expressed genes across all the conditions

# %%
import logging, sys
logging.basicConfig(stream=sys.stdout)
log = logging.getLogger()
log.setLevel(logging.INFO)

# %%
# !mkdir ./fits
# Out:
# mkdir: cannot create directory ‘./fits’: File exists

# %% [markdown]
# Run *Monod* preprocssing to set up output files/folders

# %%
dir_string,dataset_strings = monod.preprocess.construct_batch(loom_filepaths, \
                                             transcriptome_filepath, \
                                             dataset_names, \
                                             attribute_names=attribute_names,\
                                             batch_location='./fits',meta='norman_crispr_all',batch_id=1,\
                                             n_genes=3000,exp_filter_threshold=None,cf=cf)

# %%
dir_string = './fits/gg_230831_025_norman_crispr_all_1' #gg_230215_025_norman_crispr_all_1
dataset_strings = [dir_string+'/'+i for i in dataset_names]

# %%
print(dataset_strings[0])
print(len(dataset_strings))
# Out:
# ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0
# 277

# %%
# For RBPs select genes with changes in relevant parameter:

# splicing factors:
# ['SNRP70','HRNPLL','MBNL2','MBNL1','SF3B1','U2AF','SRSF2']

# terminal erythropoiesis
# other: ['RBM38','HNRNPA1']
# target: ['EBP41','EBP41']

# AUF1 paper
# degradation reps:['AUF1',]
# targets:['TNF','IL8','IL10','PLEK2','BCL2']

# Regulation 2001
# ['MYC'] degraded in K562 cells --> megakaryoblasts


# RBPS in erythropoiesis https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6066521/ + original paper:
# diff markers: ['GATA1','KLF1','SLC25A37','CD235a','GYPA',
# 'IGBP1','eIF4E','ATF4','PPR15a','GADD34']

# deg: ['PABPC1','PABPC4','CPEB4','ZFP36','ZFP36L1','ZFP36L2','ELAV1','CSDE1']
# targets: ['HBA1','KIT','eIF3','STAT5B','PABPC1']


# Deg genes elife paper:
# elife-49708-supp1-v2.xlsx, DDX6 knockout results
# deg: ['DDX6','DCP1','DCP2','PAT1B','XRN1','SMG6','YTHDF2','ATXN2']
# #possible list of target cited https://elifesciences.org/articles/49708#content 


# Add genes from perturb-sci-kinetics:

# trans_init_syn_chrom = ['GTF2E1', 'TAF2', 'MED21','MNAT1','POLR2B','POLR2K','SMC3',
# 'RAD21','CTCF','ARID1A' ]
# splic_proc = ['NCBP1','LSM2', 'LSM4', 'PRPF38B', 'HNRNPK','CPSF2', 'CPSF6', 'NUDT21', 'CSTF3']
# oxphos = ['GAPDH', 'NDUFS2', 'ACO2']
# trans_silence = ['GAPDH, NDUFS2, 191 ACO2']
# deg_process = ['UPF1', 'UPF2', 'SMG5', 'SMG7','EXOSC2', 'EXOSC5', 'EXOSC6',
# 'CSTF3', 'CPSF2', 'CPSF6', 'NUDT21', 'XRN2','RNMT', 'NCBP1' ]
# --------

#'ARRDC3' downregulates 'ITGB4'
#SNAI1 repressed CDH1 (Cadherin),NANOG, NR5A2, KIT -> https://stemcellsjournals.onlinelibrary.wiley.com/doi/full/10.1002/stem.1898
# Apoptosis--> global mRNA decay ,
#CBL targets -->EGFR, FLT3, KIT, MPL https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4775400/
#ubash3b (also + CBL) targets --> 
#ETS/FEV trans factors
#KMT2A methylation 
#MIDN degrades FOSB, EGR1, NR4A1, IRF4, NEUROD1, PAX8, GATA1 https://www.science.org/doi/10.1126/science.adh5021
#RUNX1T1 --> PTK2B, RBFOX2 alt splicing https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7822815/

# %% [markdown]
# Add all the genes that were single targets, to be fit

# %%
first = [i.split('_')[0] for i in ids]
secnd = [i.split('_')[1] for i in ids]

all_targets = np.unique(first+secnd)

# %%
all_targets
# Out:
# array(['AHR', 'ARID1A', 'ARRDC3', 'ATL1', 'BAK1', 'BCL2L11', 'BCORL1',
#        'BPGM', 'C19orf26', 'C3orf72', 'CBFA2T3', 'CBL', 'CDKN1A',
#        'CDKN1B', 'CDKN1C', 'CEBPA', 'CEBPB', 'CEBPE', 'CELF2', 'CITED1',
#        'CKS1B', 'CLDN6', 'CNN1', 'CNNM4', 'COL1A1', 'COL2A1', 'CSRNP1',
#        'DLX2', 'DUSP9', 'EGR1', 'ELMSAN1', 'ETS2', 'FEV', 'FOSB', 'FOXA1',
#        'FOXA3', 'FOXF1', 'FOXL2', 'FOXO4', 'GLB1L2', 'HES7', 'HK2',
#        'HNF4A', 'HOXA13', 'HOXB9', 'HOXC13', 'IER5L', 'IGDCC3', 'IKZF3',
#        'IRF1', 'ISL2', 'JUN', 'KIAA1804', 'KIF18B', 'KIF2C', 'KLF1',
#        'KMT2A', 'LHX1', 'LYL1', 'MAML2', 'MAP2K3', 'MAP2K6', 'MAP4K3',
#        'MAP4K5', 'MAP7D1', 'MAPK1', 'MEIS1', 'MIDN', 'NCL', 'NIT1',
#        'NegCtrl0', 'NegCtrl1', 'NegCtrl10', 'NegCtrl11', 'OSR2', 'PLK4',
#        'POU3F2', 'PRDM1', 'PRTG', 'PTPN1', 'PTPN12', 'PTPN13', 'PTPN9',
#        'RHOXF2', 'RREB1', 'RUNX1T1', 'S1PR2', 'SAMD1', 'SET', 'SGK1',
#        'SLC38A2', 'SLC4A1', 'SLC6A9', 'SNAI1', 'SPI1', 'STIL', 'TBX2',
#        'TBX3', 'TGFBR2', 'TMSB4X', 'TP73', 'TSC22D1', 'UBASH3A',
#        'UBASH3B', 'ZBTB1', 'ZBTB10', 'ZBTB25', 'ZC3HAV1', 'ZNF318'],
#       dtype='<U9')

# %%
new_genes = ['ITGB4','CDH1','NANOG', 'NR5A2', 'KIT', 'EGFR', 'FLT3', 'MPL',
            'FOSB', 'EGR1', 'NR4A1', 'IRF4', 'NEUROD1', 'PAX8', 'GATA1','PTK2B', 'RBFOX2']

# %%
ds = lp.connect(loom_filepaths[0])
g_names = ds.ra['gene_name']
ds.close()

# %%
#Filter out genes not in original data
markers = [i for i in new_genes if i in g_names]
markers = np.unique(markers+list(all_targets))

#Filter for genes in transcriptome reference + without duplicate references
annots=pd.read_csv('./gg_200525_genome_polyA_cum_3',delim_whitespace=True,header=None)

filt_markers = [m for m in markers if m in list(annots[0])]
len(filt_markers)
# Out:
# 116

# %%
#Add genes to genes.csv file created by Monod (for inference)
to_change = pd.read_csv('./fits/gg_230831_025_norman_crispr_all_1/genes.csv',header=None)
first_sel = list(to_change.iloc[0])

# %%
uniq = [i for i in filt_markers if i not in first_sel]
first_sel = first_sel+uniq

# %%
#Save to original genes.csv
new_pd = pd.DataFrame(columns=range(len(first_sel)))
new_pd.loc[0] = first_sel
new_pd.to_csv('./fits/gg_230831_025_norman_crispr_all_1/genes.csv',header=None,index=None)

# %%
# # Test reading file in to see if it worked
# test = pd.read_csv('./fits/gg_230831_025_norman_crispr_all_1/genes.csv',header=None)

# %% [markdown]
# ## **Run *Monod* Parameter Inference**

# %%
#Define bounds, from 20220930_normanfit_monod.ipynb
phys_lb = [-2.0, -1.8, -1.8 ] #-1.0, -1.8, -1.8
phys_ub = [4.2, 2.5, 2.5] #4.2, 2.5, 3.5
samp_lb = [-7.157894736842105, -1.525] #-7.5, -2
samp_ub = [-7.157894736842105, -1.525] #-5.5, 0
# gridsize = [5,6]
gridsize = [1,1]  #No grid because we already know this value from the norman_perturb_prediction notebook

# %%
result_strings = []
for i in range(n_datasets):
    fitmodel = monod.cme_toolbox.CMEModel('Bursty','Poisson')
    inference_parameters = monod.inference.InferenceParameters(phys_lb,phys_ub,samp_lb,samp_ub,gridsize,\
                dataset_strings[i],fitmodel,use_lengths = True,
                gradient_params = {'max_iterations':10,'init_pattern':'moments','num_restarts':5})
    search_data = monod.extract_data.extract_data(loom_filepaths[i], transcriptome_filepath, dataset_names[i],
                dataset_strings[i], dir_string, dataset_attr_names=attribute_names,cf=cf[i])
    full_result_string = inference_parameters.fit_all_grid_points(30,search_data)

    result_strings.append(full_result_string)

# %%
result_strings = [i+'/Bursty_Poisson_1x1/grid_scan_results.res' for i in dataset_strings]
print(result_strings[0])
# Out:
# ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res

# %% [markdown]
# ## **QC and Analysis of Results**

# %%
# a e s t h e t i c s
from matplotlib.colors import ListedColormap

#all
col_gold = [203/255,197/255,149/255]
col_gray = [116/255,112/255,113/255]
col_red = [212/255,107/255,75/255]
col_b = ['#1B9AAA']
col_beta = ['#9fcbee']
col_gamma =['#3C50B1']
col_expr = ['#9299A0']

### SI figures
ms = 0.7
lw = ms
ms_fail = 1
alf = 0.3
alf_fail = 0.5
sifig_aesth = (ms,lw,ms_fail,alf,alf_fail)

### Body figures
ms = 2
lw = ms
ms_fail = 2
alf = 0.3
alf_fail = 0.8
msfig_aesth = (ms,lw,ms_fail,alf,alf_fail)

markerstyle = None

c_highlight = col_red
c1 = [173/255,214/255,200/255]
c2 = [59/255,131/255,130/255]
ncol=20
cmap = ListedColormap(np.array([np.linspace(c2[j],c1[j],ncol) for j in range(3)]).T)

# %%
n_datasets
# Out:
# 277

# %%
#Read back in data
sr_arr = [monod.analysis.load_search_results(r) for r in result_strings]
# Out:
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl1_NegCtrl0__NegCtrl1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl11_NegCtrl0__NegCtrl11_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_RUNX1T1__CEBPE_RUNX1T1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_KLF1_NegCtrl0__KLF1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TBX3_TBX2__TBX3_TBX2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SLC4A1_NegCtrl0__SLC4A1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ETS2_CNN1__ETS2_CNN1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_UBASH3B_OSR2__UBASH3B_OSR2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9_ETS2__DUSP9_ETS2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_BAK1__NegCtrl0_BAK1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_KLF1__NegCtrl0_KLF1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_ETS2__NegCtrl0_ETS2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9_NegCtrl0__DUSP9_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_BAK1_NegCtrl0__BAK1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SET_KLF1__SET_KLF1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CEBPE__NegCtrl0_CEBPE/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CBL_NegCtrl0__CBL_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SET_CEBPE__SET_CEBPE/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SET_NegCtrl0__SET_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZNF318_NegCtrl0__ZNF318_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_LHX1_ELMSAN1__LHX1_ELMSAN1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOSB_NegCtrl0__FOSB_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_MAML2_NegCtrl0__MAML2_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_LYL1_IER5L__LYL1_IER5L/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZC3HAV1_HOXC13__ZC3HAV1_HOXC13/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_UBASH3B__NegCtrl0_UBASH3B/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_UBASH3B_NegCtrl0__UBASH3B_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_BCL2L11_NegCtrl0__BCL2L11_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_MAP2K3_ELMSAN1__MAP2K3_ELMSAN1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_MAP2K3_NegCtrl0__MAP2K3_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_MAP2K3_MAP2K6__MAP2K3_MAP2K6/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_NegCtrl0__CEBPE_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_C19orf26_NegCtrl0__C19orf26_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_AHR_NegCtrl0__AHR_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SLC6A9_NegCtrl0__SLC6A9_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_UBASH3B_UBASH3A__UBASH3B_UBASH3A/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXF1_NegCtrl0__FOXF1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TMSB4X_NegCtrl0__TMSB4X_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_S1PR2_NegCtrl0__S1PR2_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_BCORL1_NegCtrl0__BCORL1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0
A_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1C_NegCtrl0__CDKN1C_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_IER5L__NegCtrl0_IER5L/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_HOXC13__NegCtrl0_HOXC13/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_SAMD1__NegCtrl0_SAMD1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_POU3F2_CBFA2T3__POU3F2_CBFA2T3/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA3_FOXA1__FOXA3_FOXA1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CEBPA__NegCtrl0_CEBPA/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CITED1_NegCtrl0__CITED1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXO4_NegCtrl0__FOXO4_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_PTPN12__NegCtrl0_PTPN12/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPB_OSR2__CEBPB_OSR2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SPI1_NegCtrl0__SPI1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CEBPB__NegCtrl0_CEBPB/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXF1_HOXB9__FOXF1_HOXB9/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PTPN9_NegCtrl0__PTPN9_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_SNAI1__NegCtrl0_SNAI1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXL2_MEIS1__FOXL2_MEIS1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NIT1_NegCtrl0__NIT1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA1_FOXL2__FOXA1_FOXL2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXF1_FOXL2__FOXF1_FOXL2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_LYL1_CEBPB__LYL1_CEBPB/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FEV_NegCtrl0__FEV_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SAMD1_ZBTB1__SAMD1_ZBTB1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CBL_TGFBR2__CBL_TGFBR2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CDKN1B__NegCtrl0_CDKN1B/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1A_NegCtrl0__CDKN1A_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_IER5L_NegCtrl0__IER5L_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9_SNAI1__DUSP9_SNAI1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZBTB10_ELMSAN1__ZBTB10_ELMSAN1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_CEBPA__CEBPE_CEBPA/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_SPI1__CEBPE_SPI1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CNN1_UBASH3A__CNN1_UBASH3A/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CDKN1A__NegCtrl0_CDKN1A/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA3_FOXF1__FOXA3_FOXF1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_BCL2L11_BAK1__BCL2L11_BAK1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TGFBR2_IGDCC3__TGFBR2_IGDCC3_1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_STIL__NegCtrl0_STIL/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOSB_CEBPE__FOSB_CEBPE/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_STIL_NegCtrl0__STIL_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_IGDCC3_ZBTB25__IGDCC3_ZBTB25/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_IGDCC3_PRTG__IGDCC3_PRTG/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TGFBR2_IGDCC3__TGFBR2_IGDCC3_2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1B_CDKN1A__CDKN1B_CDKN1A/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SNAI1_DLX2__SNAI1_DLX2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA3_FOXL2__FOXA3_FOXL2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_HES7_NegCtrl0__HES7_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1C_CDKN1A__CDKN1C_CDKN1A/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_CEBPB__CEBPE_CEBPB/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PLK4_NegCtrl0__PLK4_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1C_CDKN1B__CDKN1C_CDKN1B/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_KIF18B_KIF2C__KIF18B_KIF2C/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXL2_HOXB9__FOXL2_HOXB9/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_HOXC13_NegCtrl0__HOXC13_NegCtrl0_2/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZBTB10_NegCtrl0__ZBTB10_NegCtrl0_1/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PLK4_STIL__PLK4_STIL/Bursty_Poisson_1x1/grid_scan_results.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SAMD1_TGFBR2__SAMD1_TGFBR2/Bursty_Poisson_1x1/grid_scan_results.res.

# %%
#--- Reject genes from goodness of fit testing and  calculate std error -----
for i in range(len(sr_arr)):
    sr = sr_arr[i]
    sr.set_sampling_optimum(sr.sp.sampl_vals.index((-7.157894736842105, -1.525)))  
    
    sd = monod.analysis.load_search_data(dataset_strings[i]+'/raw.sd')
    _=sr.chisquare_testing(sd,reject_at_bounds=True) #EPS=1e-20
    sr.compute_sigma(sd,num_cores=30)
    
    monod.analysis.make_batch_analysis_dir([sr],dir_string)
    sr.update_on_disk()
# Out:
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0/raw.sd.
# INFO:root:Chi-square computation complete. Rejected 64 genes out of 3084. Runtime: 20.1 seconds.
# INFO:root:Computing local Hessian.
# INFO:root:Starting parallelized Hessian computation.
# INFO:root:Parallelized Hessian computation complete.
# INFO:root:Gene 124 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 144 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 260 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 264 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 542 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 677 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1043 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1137 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1363 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1366 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1466 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1593 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1673 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1697 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1899 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2111 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2408 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2429 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2628 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2879 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3003 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3007 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3012 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3028 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3041 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3044 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3045 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3063 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3065 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3071 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3080 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Standard error of the MLE computation complete. Runtime: 118.9 seconds.
# INFO:root:Directory ./fits/gg_230831_025_norman_crispr_all_1/analysis_figures created.
# /home/tchari/monod/src/monod/inference.py:1370: RuntimeWarning: invalid value encountered in sqrt
#   sigma[gene_index, :] = np.sqrt(np.diag(hess_inv)) / np.sqrt(
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl1_NegCtrl0__NegCtrl1_NegCtrl0/raw.sd.
# INFO:root:Chi-square computation complete. Rejected 71 genes out of 3084. Runtime: 19.7 seconds.
# INFO:root:Computing local Hessian.
# INFO:root:Starting parallelized Hessian computation.
# INFO:root:Parallelized Hessian computation complete.
# INFO:root:Gene 36 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 264 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 601 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 643 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 775 ran into singularity; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1096 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1137 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1223 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1509 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1738 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1899 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2004 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2111 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2200 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2355 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2583 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2591 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3010 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3012 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3014 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3018 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3028 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3029 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3045 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3046 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3047 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3065 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3071 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3072 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3080 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# /home/tchari/monod/src/monod/inference.py:1370: RuntimeWarning: invalid value encountered in sqrt
#   sigma[gene_index, :] = np.sqrt(np.diag(hess_inv)) / np.sqrt(
# INFO:root:Standard error of the MLE computation complete. Runtime: 134.8 seconds.
# INFO:root:Directory ./fits/gg_230831_025_norman_crispr_all_1/analysis_figures already exists.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl11_NegCtrl0__NegCtrl11_NegCtrl0/raw.sd.
# INFO:root:Chi-square computation complete. Rejected 70 genes out of 3084. Runtime: 19.7 seconds.
# INFO:root:Computing local Hessian.
# INFO:root:Starting parallelized Hessian computation.
# INFO:root:Parallelized Hessian computation complete.
# INFO:root:Gene 321 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene
gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2343 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2381 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2497 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2523 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2565 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# /home/tchari/monod/src/monod/inference.py:1370: RuntimeWarning: invalid value encountered in sqrt
#   sigma[gene_index, :] = np.sqrt(np.diag(hess_inv)) / np.sqrt(
# INFO:root:Gene 2583 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2632 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2869 ran into singularity; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2963 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3030 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3045 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3072 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Standard error of the MLE computation complete. Runtime: 101.1 seconds.
# INFO:root:Directory ./fits/gg_230831_025_norman_crispr_all_1/analysis_figures already exists.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9_ETS2__DUSP9_ETS2/raw.sd.
# INFO:root:Chi-square computation complete. Rejected 173 genes out of 3084. Runtime: 18.1 seconds.
# INFO:root:Computing local Hessian.
# INFO:root:Starting parallelized Hessian computation.
# INFO:root:Parallelized Hessian computation complete.
# INFO:root:Gene 17 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 69 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 94 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 140 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 156 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 164 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 314 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 354 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 397 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 502 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 527 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 532 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# ...
# INFO:root:Gene 383 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 431 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 441 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 462 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 465 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 490 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 507 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 523 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 541 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 553 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 560 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 592 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 601 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 606 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 614 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 627 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 647 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 657 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 678 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 679 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 687 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 698 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 723 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 736 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 744 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 753 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 754 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 764 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 772 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 798 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 836 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 871 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 873 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 897 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 899 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 909 ran into singularity; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 924 ran into singularity; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 935 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 948 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 953 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 956 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 993 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1028 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1137 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1179 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1204 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1209 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1218 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1243 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1309 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1311 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1323 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1324 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1344 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1345 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1351 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1392 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1405 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1418 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1426 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1435 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1449 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1453 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1454 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1466 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1483 ran into singularity; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1503 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1507 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1595 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1597 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1604 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1606 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1612 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1620 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1668 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1686 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1697 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1705 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1710 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1724 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1730 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1737 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1747 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1782 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1820 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1871 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1903 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1918 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# /home/tchari/monod/src/monod/inference.py:1370: RuntimeWarning: invalid value encountered in sqrt
#   sigma[gene_index, :] = np.sqrt(np.diag(hess_inv)) / np.sqrt(
# INFO:root:Gene 1943 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1953 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1981 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1987 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2001 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2025 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2043 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2091 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2111 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2147 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2153 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2162 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2166 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2193 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2205 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2233 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2248 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2266 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2269 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2296 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2306 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2329 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2334 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2363 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2396 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2404 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2436 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2442 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2471 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2485 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2523 ran into singularity; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2551 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2560 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2570 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2583 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2587 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2591 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2593 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2615 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2617 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2632 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2633 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2648 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2688 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2691 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2720 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2737 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2744 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2764 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2788 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2801 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2827 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2836 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2842 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2890 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2911 ran into singularity; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2921 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2923 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2976 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2983 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3000 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3013 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3026 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3028 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3038 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3039 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3046 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3047 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3062 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 3076 ran into singularity; replaced with mean. (Search converged to local minimum?)
# INFO:root:Standard error of the MLE computation complete. Runtime: 71.6 seconds.
# INFO:root:Directory ./fits/gg_230831_025_norman_crispr_all_1/analysis_figures already exists.

# %%
#Read back in data
sr_arr = [monod.analysis.load_search_results(r[:-4]+'_upd.res') for r in result_strings]
# Out:
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl1_NegCtrl0__NegCtrl1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl11_NegCtrl0__NegCtrl11_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_RUNX1T1__CEBPE_RUNX1T1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_KLF1_NegCtrl0__KLF1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TBX3_TBX2__TBX3_TBX2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SLC4A1_NegCtrl0__SLC4A1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ETS2_CNN1__ETS2_CNN1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_UBASH3B_OSR2__UBASH3B_OSR2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9_ETS2__DUSP9_ETS2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_BAK1__NegCtrl0_BAK1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_KLF1__NegCtrl0_KLF1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_ETS2__NegCtrl0_ETS2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9_NegCtrl0__DUSP9_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_BAK1_NegCtrl0__BAK1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SET_KLF1__SET_KLF1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CEBPE__NegCtrl0_CEBPE/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CBL_NegCtrl0__CBL_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SET_CEBPE__SET_CEBPE/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SET_NegCtrl0__SET_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZNF318_NegCtrl0__ZNF318_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_LHX1_ELMSAN1__LHX1_ELMSAN1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOSB_NegCtrl0__FOSB_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_MAML2_NegCtrl0__MAML2_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_LYL1_IER5L__LYL1_IER5L/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZC3HAV1_HOXC13__ZC3HAV1_HOXC13/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_UBASH
Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_CNN1__CEBPE_CNN1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NCL_NegCtrl0__NCL_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_HNF4A_NegCtrl0__HNF4A_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_IKZF3__NegCtrl0_IKZF3/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PTPN12_NegCtrl0__PTPN12_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ARID1A_NegCtrl0__ARID1A_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1C_NegCtrl0__CDKN1C_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_IER5L__NegCtrl0_IER5L/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_HOXC13__NegCtrl0_HOXC13/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_SAMD1__NegCtrl0_SAMD1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_POU3F2_CBFA2T3__POU3F2_CBFA2T3/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA3_FOXA1__FOXA3_FOXA1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CEBPA__NegCtrl0_CEBPA/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CITED1_NegCtrl0__CITED1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXO4_NegCtrl0__FOXO4_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_PTPN12__NegCtrl0_PTPN12/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPB_OSR2__CEBPB_OSR2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SPI1_NegCtrl0__SPI1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CEBPB__NegCtrl0_CEBPB/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXF1_HOXB9__FOXF1_HOXB9/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PTPN9_NegCtrl0__PTPN9_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_SNAI1__NegCtrl0_SNAI1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXL2_MEIS1__FOXL2_MEIS1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NIT1_NegCtrl0__NIT1_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA1_FOXL2__FOXA1_FOXL2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXF1_FOXL2__FOXF1_FOXL2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_LYL1_CEBPB__LYL1_CEBPB/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FEV_NegCtrl0__FEV_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SAMD1_ZBTB1__SAMD1_ZBTB1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CBL_TGFBR2__CBL_TGFBR2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CDKN1B__NegCtrl0_CDKN1B/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1A_NegCtrl0__CDKN1A_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_IER5L_NegCtrl0__IER5L_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9_SNAI1__DUSP9_SNAI1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZBTB10_ELMSAN1__ZBTB10_ELMSAN1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_CEBPA__CEBPE_CEBPA/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_SPI1__CEBPE_SPI1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CNN1_UBASH3A__CNN1_UBASH3A/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CDKN1A__NegCtrl0_CDKN1A/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA3_FOXF1__FOXA3_FOXF1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_BCL2L11_BAK1__BCL2L11_BAK1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TGFBR2_IGDCC3__TGFBR2_IGDCC3_1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_STIL__NegCtrl0_STIL/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOSB_CEBPE__FOSB_CEBPE/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_STIL_NegCtrl0__STIL_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_IGDCC3_ZBTB25__IGDCC3_ZBTB25/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_IGDCC3_PRTG__IGDCC3_PRTG/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TGFBR2_IGDCC3__TGFBR2_IGDCC3_2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1B_CDKN1A__CDKN1B_CDKN1A/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SNAI1_DLX2__SNAI1_DLX2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA3_FOXL2__FOXA3_FOXL2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_HES7_NegCtrl0__HES7_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1C_CDKN1A__CDKN1C_CDKN1A/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_CEBPB__CEBPE_CEBPB/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PLK4_NegCtrl0__PLK4_NegCtrl0/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1C_CDKN1B__CDKN1C_CDKN1B/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_KIF18B_KIF2C__KIF18B_KIF2C/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXL2_HOXB9__FOXL2_HOXB9/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_HOXC13_NegCtrl0__HOXC13_NegCtrl0_2/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZBTB10_NegCtrl0__ZBTB10_NegCtrl0_1/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PLK4_STIL__PLK4_STIL/Bursty_Poisson_1x1/grid_scan_results_upd.res.
# INFO:root:Grid scan results loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SAMD1_TGFBR2__SAMD1_TGFBR2/Bursty_Poisson_1x1/grid_scan_results_upd.res.

# %%
#Get all params for all conditions and genes
n_genes = sr_arr[0].n_genes
n_phys_pars = sr_arr[0].sp.n_phys_pars
par_vals_uncorrected = np.zeros((n_datasets,n_genes,n_phys_pars))



for j in range(n_datasets):
    par_vals_uncorrected[j,:,:] = sr_arr[j].phys_optimum

# %%
#Read in and save raw counts
sd_arr = []
for i in range(len(sr_arr)): #inds_neg:
    sd_arr += [monod.analysis.load_search_data(dataset_strings[i]+'/raw.sd')]
# Out:
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl1_NegCtrl0__NegCtrl1_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl11_NegCtrl0__NegCtrl11_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_RUNX1T1__CEBPE_RUNX1T1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_KLF1_NegCtrl0__KLF1_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TBX3_TBX2__TBX3_TBX2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SLC4A1_NegCtrl0__SLC4A1_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ETS2_CNN1__ETS2_CNN1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_UBASH3B_OSR2__UBASH3B_OSR2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9_ETS2__DUSP9_ETS2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_BAK1__NegCtrl0_BAK1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_KLF1__NegCtrl0_KLF1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_ETS2__NegCtrl0_ETS2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9
HOXB9/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PTPN9_NegCtrl0__PTPN9_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_SNAI1__NegCtrl0_SNAI1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXL2_MEIS1__FOXL2_MEIS1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NIT1_NegCtrl0__NIT1_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA1_FOXL2__FOXA1_FOXL2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXF1_FOXL2__FOXF1_FOXL2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_LYL1_CEBPB__LYL1_CEBPB/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FEV_NegCtrl0__FEV_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SAMD1_ZBTB1__SAMD1_ZBTB1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CBL_TGFBR2__CBL_TGFBR2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CDKN1B__NegCtrl0_CDKN1B/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1A_NegCtrl0__CDKN1A_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_IER5L_NegCtrl0__IER5L_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_DUSP9_SNAI1__DUSP9_SNAI1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZBTB10_ELMSAN1__ZBTB10_ELMSAN1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_CEBPA__CEBPE_CEBPA/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_SPI1__CEBPE_SPI1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CNN1_UBASH3A__CNN1_UBASH3A/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_CDKN1A__NegCtrl0_CDKN1A/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA3_FOXF1__FOXA3_FOXF1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_BCL2L11_BAK1__BCL2L11_BAK1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TGFBR2_IGDCC3__TGFBR2_IGDCC3_1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_NegCtrl0_STIL__NegCtrl0_STIL/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOSB_CEBPE__FOSB_CEBPE/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_STIL_NegCtrl0__STIL_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_IGDCC3_ZBTB25__IGDCC3_ZBTB25/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_IGDCC3_PRTG__IGDCC3_PRTG/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_TGFBR2_IGDCC3__TGFBR2_IGDCC3_2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1B_CDKN1A__CDKN1B_CDKN1A/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SNAI1_DLX2__SNAI1_DLX2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXA3_FOXL2__FOXA3_FOXL2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_HES7_NegCtrl0__HES7_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1C_CDKN1A__CDKN1C_CDKN1A/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CEBPE_CEBPB__CEBPE_CEBPB/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PLK4_NegCtrl0__PLK4_NegCtrl0/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_CDKN1C_CDKN1B__CDKN1C_CDKN1B/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_KIF18B_KIF2C__KIF18B_KIF2C/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_FOXL2_HOXB9__FOXL2_HOXB9/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_HOXC13_NegCtrl0__HOXC13_NegCtrl0_2/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_ZBTB10_NegCtrl0__ZBTB10_NegCtrl0_1/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_PLK4_STIL__PLK4_STIL/raw.sd.
# INFO:root:Search data loaded from ./fits/gg_230831_025_norman_crispr_all_1/norman_allcrispr_SAMD1_TGFBR2__SAMD1_TGFBR2/raw.sd.

# %%
#Save Spliced means for future analysis
s_means = np.zeros((n_datasets,n_genes))

for j in range(n_datasets):
    s_means[j,:] = np.mean(sd_arr[j].layers[1,:,:],axis=1)

# %% [markdown]
# **Validation of Activated Genes**

# %%
#Find ctrls in list
search = ['NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0','NegCtrl11_NegCtrl0__NegCtrl11_NegCtrl0',
          'NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0']

control_filt = [((search[0] in i) or (search[1] in i) or (search[2] in i)) for i in dataset_strings  ]
control_inds = np.array(range(len(dataset_strings)))[control_filt]


palette={'b':col_b[0],'beta':col_beta[0],'gamma':col_gamma[0],'expr':col_expr[0]}

# %%
np.sum(control_filt)
# Out:
# 3

# %% [markdown]
# Get FCs for all the targeted genes

# %%
#Break up result_strings by _, get genes (first two)
actGenes = [i.split('_')[8:10] for i in dataset_strings] #CRISPR activated genes

#Remove genes with two 'Neg' in them
uniq = np.unique(actGenes)
uniq = [i for i in uniq if 'Neg' not in i]

all_not_rej = ~sr_arr[control_inds[0]].rejected_genes & ~sr_arr[control_inds[1]].rejected_genes & ~sr_arr[control_inds[2]].rejected_genes


fcs = []
param_nm = []
cond_nm = []
means = []
errs = [] #std error for params
var = [] #vars in FCs
means_params = []
#For each gene
ctrls = par_vals_uncorrected[control_filt,:,:]
gene_names = sr_arr[0].gene_names

uniq = [i for i in uniq if i in gene_names[all_not_rej]]
print(len(uniq))

for u in uniq:
    g_filt = gene_names == u
#For each result
    for i in range(len(dataset_strings)):
    #If gene and 'Neg' in it, add b,beta,gamma FC with each control
        nm = dataset_strings[i]
        if (u in nm) and ('Neg' in nm) and (np.sum(g_filt != 0)): #Not plotting dual conditions

            c = ctrls[:,g_filt,:]
            perturb = par_vals_uncorrected[i,g_filt,:]
            
            calcs = [perturb[0,0] - c[0,0,0],perturb[0,0] - c[1,0,0],perturb[0,0] - c[2,0,0],
                    perturb[0,1] - c[0,0,1],perturb[0,1] - c[1,0,1],perturb[0,1] - c[2,0,1],
                   perturb[0,2] - c[0,0,2],perturb[0,2] - c[1,0,2],perturb[0,2] - c[2,0,2]]
            
            fcs +=  calcs
            param_nm += ['b']*3+['beta']*3+['gamma']*3
            cond_nm += [u]*9
            means += [s_means[i,g_filt][0]]*9
            errs += [sr_arr[i].sigma[g_filt,0][0]]*3+[sr_arr[i].sigma[g_filt,1][0]]*3+[sr_arr[i].sigma[g_filt,2][0]]*3
            var += [np.var(calcs[0:3])]*3+[np.var(calcs[3:6])]*3+[np.var(calcs[6:9])]*3
            means_params += [np.mean(calcs[0:3])]*3+[np.mean(calcs[3:6])]*3+[np.mean(calcs[6:9])]*3

fc_res = pd.DataFrame()
fc_res['FC'] = list(np.log2(10**(np.array(fcs))))
fc_res['Param'] = param_nm
fc_res['sgRNA'] = cond_nm
fc_res['meanS'] = means
fc_res['errs'] = errs
fc_res['vars'] = var
fc_res['meanFC'] = means_params
# Out:
# 64

# %%
#Calculating propagation of error through calculations https://chem.libretexts.org/Bookshelves/Analytical_Chemistry/Supplemental_Modules_(Analytical_Chemistry)/Quantifying_Nature/Significant_Digits/Propagation_of_Error

# %%
#Average FC of bursts
np.mean(fc_res['FC'][fc_res['Param'].isin(['b'])])
# Out:
# 2.233477222155627

# %%
fc_res.head()
# Out:
#          FC Param   sgRNA     meanS      errs      vars    meanFC
# 0  1.084044     b  ARID1A  1.341317  0.123390  0.003802  0.239420
# 1  0.671309     b  ARID1A  1.341317  0.123390  0.003802  0.239420
# 2  0.630654     b  ARID1A  1.341317  0.123390  0.003802  0.239420
# 3  0.861533  beta  ARID1A  1.341317  0.120099  0.003241  0.180219
# 4  0.510043  beta  ARID1A  1.341317  0.120099  0.003241  0.180219

# %%
sns.violinplot(data=fc_res, x="Param", y="FC",palette=palette)
# Out:
# <AxesSubplot:xlabel='Param', ylabel='FC'>

# %%
plt.figure(figsize=(4.5,3))
sns.swarmplot(data=fc_res, x="Param", y="FC",palette=palette,size=4,edgecolor='black',linewidth=0.4,zorder=0)
sns.boxplot(data=fc_res, x="Param", y="FC",palette=palette,showfliers=False,boxprops={'facecolor':'None'})

plt.tight_layout()
plt.savefig('burstsize_norman.pdf')
# Out:
# /home/tchari/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 42.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/tchari/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 41.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/tchari/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 44.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(data=fc_res, x="Param", y="FC",palette=palette,)
# Out:
# <AxesSubplot:xlabel='Param', ylabel='FC'>

# %%
plt.figure(figsize=(17,5))
b_sub = fc_res[fc_res.Param.isin(['b'])]
gs = np.unique(b_sub[b_sub.FC < 0].sgRNA)
sns.boxplot(data=fc_res[fc_res.sgRNA.isin(gs)], x="sgRNA", y="FC",hue='Param',palette=palette)
# Out:
# <AxesSubplot:xlabel='sgRNA', ylabel='FC'>

# %%
plt.figure(figsize=(17,5))
b_sub = fc_res[fc_res.Param.isin(['gamma'])]
gs = np.unique(b_sub[b_sub.FC < -2].sgRNA)
sns.boxplot(data=fc_res[fc_res.sgRNA.isin(gs)], x="sgRNA", y="FC",hue='Param',palette=palette)
# Out:
# <AxesSubplot:xlabel='sgRNA', ylabel='FC'>

# %%
# a e s t h e t i c s
from matplotlib.colors import ListedColormap

#all
col_gold = [203/255,197/255,149/255]
col_gray = [116/255,112/255,113/255]
col_red = [212/255,107/255,75/255]
col_b = ['#1B9AAA']
col_beta = ['#9fcbee']
col_gamma =['#3C50B1']
col_expr = ['#9299A0']

### SI figures
ms = 0.7
lw = ms
ms_fail = 1
alf = 0.3
alf_fail = 0.5
sifig_aesth = (ms,lw,ms_fail,alf,alf_fail)

### Body figures
ms = 2
lw = ms
ms_fail = 2
alf = 0.3
alf_fail = 0.8
msfig_aesth = (ms,lw,ms_fail,alf,alf_fail)

markerstyle = None

c_highlight = col_red
c1 = [173/255,214/255,200/255]
c2 = [59/255,131/255,130/255]
ncol=20
cmap = ListedColormap(np.array([np.linspace(c2[j],c1[j],ncol) for j in range(3)]).T)

# %%
#PUT ERROR BARS HERE (GET THE AVG + VAR FOR EACH GENE )
new_beta_fcs = np.log2(10**(fc_res['meanFC'][fc_res['Param'].isin(['beta'])]))
new_gamma_fcs = np.log2(10**(fc_res['meanFC'][fc_res['Param'].isin(['gamma'])]))
new_b_fcs = np.log2(10**(fc_res['meanFC'][fc_res['Param'].isin(['b'])]))

freq = pd.DataFrame()
freq['betaFC'] = list(new_beta_fcs)
freq['gammaFC'] = list(new_gamma_fcs)
freq['bFC'] = list(new_b_fcs) #list(np.log1p(fc_res['meanS'][fc_res['Param'].isin(['gamma'])]))

freq['betaStd'] = list(np.log2(10**(np.sqrt(fc_res['vars'][fc_res['Param'].isin(['beta'])]))))
freq['gammaStd'] = list(np.log2(10**(np.sqrt(fc_res['vars'][fc_res['Param'].isin(['gamma'])]))))

fig, ax1 = plt.subplots(1, 1,figsize=(5,3))
g=sns.scatterplot(data=freq,x='betaFC', y='gammaFC',hue='bFC',edgecolor='black',ax=ax1,
                 palette='coolwarm',s=50)

ax1.errorbar(freq['betaFC'],freq['gammaFC'],freq['betaStd'],freq['gammaStd'],
                     marker=markerstyle,ms=ms,c='lightgrey',alpha=alf,
                linestyle='None',linewidth=lw/1.5,zorder=-100)


#plt.plot(freq['betaFC'],[1]*len(freq['betaFC']),'--',color=col_red,linewidth=3,alpha=0.4) 
rho = np.corrcoef(freq.betaFC,freq.gammaFC)[0][1]
p = scipy.stats.spearmanr(freq.betaFC,freq.gammaFC)[0]

# ax1.text(.05,.8,r'$r$ = {:.2f}'.format(rho),fontsize=14,transform=ax1.transAxes)
# ax1.text(.05,.9,r'$\rho$ = {:.2f}'.format(p),fontsize=14,transform=ax1.transAxes)
   
xl = ax1.get_xlim()
ax1.plot(xl,xl,'--',color=col_gray,linewidth=3,alpha=0.4)
sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.savefig('burstfreq_norman.pdf')

# %%
sns.jointplot(data=freq, x="betaFC", y="gammaFC",kind='kde')
#sns.jointplot(data=freq, x="betaFC", y="gammaFC")

# %% [markdown]
# **Which conditions and genes are 'informative'**
#
# Use Fisher Info (from Hessian of KLD)

# %%
len(sr_arr)
# Out:
# 277

# %%
#Fisher information...
b_info = []
beta_info = []
gamma_info = []

n_cells = []
avg_depth = []

#Get average genes detected
genes_det = []


for s in range(len(sr_arr)):
    hess = [sr_arr[s].par_fun_hess(x)
            for x in zip(range(sr_arr[s].n_genes), [sd_arr[s]] * sr_arr[s].n_genes)
            ]
    b_sum = 0
    beta_sum = 0
    gamma_sum = 0
    for h in range(len(hess)):
        b_sum += hess[h][0,0]
        beta_sum += hess[h][1,1]
        gamma_sum += hess[h][2,2]  #Sum information per parameter over genes
    
    b_info += [b_sum]
    beta_info += [beta_sum]
    gamma_info += [gamma_sum]
        
    n_cells += [sd_arr[s].n_cells]
    avg_depth += [np.mean(np.sum(sd_arr[s].layers[1]+sd_arr[s].layers[0] ,axis=0))]  #Avg read depth
    
    genes_det += [np.mean(np.sum((sd_arr[s].layers[1]+sd_arr[s].layers[0])>0,axis=0))]

# %%
fish_df = pd.DataFrame()
fish_df['b Info'] = b_info
fish_df['beta Info'] = beta_info
fish_df['gamma Info'] = gamma_info
fish_df['No. Cells'] = n_cells
fish_df['Avg. Depth'] = avg_depth
fish_df['No. Genes'] = genes_det
fish_df.head()
# Out:
#          b Info    beta Info    gamma Info  No. Cells   Avg. Depth  \
# 0  20659.395015  9504.147494  13674.970249       3255  7266.692473
# 1  21023.708712  9486.309782  14183.223308       2679  7346.237402
# 2  21063.191444  9505.302978  14076.055982       2622  7342.135393
# 3  20996.542102  9458.375207  14040.984532       2362  7301.011008
# 4  20512.476222  9304.672758  13594.734653       1018  6757.571709
#
#      No. Genes
# 0  2038.782488
# 1  2043.751027
# 2  2045.002670
# 3  2040.676545
# 4  1995.998035

# %%
plt.hist(list(fish_df['No. Genes']))
print(np.mean(fish_df['No. Genes']))
# Out:
# 1975.40636394603

# %%
if_single = ['Neg' in i for i in dataset_names]
fish_df['Single Cond'] = if_single

# %%
palette
# Out:
# {'b': '#1B9AAA', 'beta': '#9fcbee', 'gamma': '#3C50B1', 'expr': '#9299A0'}

# %%
fig, ax = plt.subplots(nrows=3,ncols=2,figsize=(8,8))
rows = ['b Info','beta Info','gamma Info']
r_palette = {'b Info': '#1B9AAA', 'beta Info': '#9fcbee', 'gamma Info': '#3C50B1'}
for rs in range(len(rows)):
    row = rows[rs]
    cl = r_palette[row]
    
    g1=sns.scatterplot(data=fish_df, x='No. Cells',y=row,color=cl,
                   edgecolor='black',linewidth=0.5,s=50,ax=ax[rs,0],alpha=0.7)
    
    g2=sns.scatterplot(data=fish_df, x='Avg. Depth',y=row,color=cl,
                   edgecolor='black',linewidth=0.5,s=50,ax=ax[rs,1],alpha=0.7)
    
    rho = np.corrcoef(fish_df['No. Cells'],fish_df[row])[0][1]
    p = scipy.stats.spearmanr(fish_df['No. Cells'],fish_df[row])[0]
    
    ax[rs,0].text(.62,.1,r'$r$ = {:.2f}'.format(rho),fontsize=14,transform=ax[rs,0].transAxes)
    ax[rs,0].text(.62,.22,r'$\rho$ = {:.2f}'.format(p),fontsize=14,transform=ax[rs,0].transAxes)
    
    ax[rs,0].set_yscale('log')
    ax[rs,0].set_xscale('log')
    
    rho = np.corrcoef(fish_df['Avg. Depth'],fish_df[row])[0][1]
    p = scipy.stats.spearmanr(fish_df['Avg. Depth'],fish_df[row])[0]
    
    ax[rs,1].text(.62,.1,r'$r$ = {:.2f}'.format(rho),fontsize=14,transform=ax[rs,1].transAxes)
    ax[rs,1].text(.62,.22,r'$\rho$ = {:.2f}'.format(p),fontsize=14,transform=ax[rs,1].transAxes)
    
    ax[rs,1].set_yscale('log')
    ax[rs,1].set_xscale('log')

    
    #ax[rs,1].yaxis.set_ticklabels([''])
 
    
plt.tight_layout()
plt.savefig('norman_info_cells_depth.pdf')

# %%
'CBL' in dataset_strings[0]
# Out:
# False

# %% [markdown]
# **Get burst FCs for genes in CBL/CNN1 and DUSP9/ETS2 conditions**

# %%
#Dual conditions to find
uniq = [['CBL','CNN1'],['DUSP9','ETS2']]

#all_not_rej = ~sr_arr[control_inds[0]].rejected_genes & ~sr_arr[control_inds[1]].rejected_genes & ~sr_arr[control_inds[2]].rejected_genes

fcs = []
param_nm = []
cond_nm = []
means = []
errs = [] #std error for params
var = [] #vars in FCs
means_params = []
genes_names = []
gene_names = sr_arr[0].gene_names

#For each gene
ctrls = par_vals_uncorrected[control_filt,:,:]

for u in uniq:

#For each result
    for i in range(len(dataset_strings)):
    #If found dual condition, add b,beta,gamma FC with each control
        nm = dataset_strings[i]
        if ((u[0] in nm) and (u[1] in nm)): #dual conditions
            g_filt = ~sr_arr[i].rejected_genes
            print(np.sum(g_filt))

            c = ctrls[:,g_filt,:]
            perturb = par_vals_uncorrected[i,g_filt,:]
            
            calcs = list(perturb[:,0] - c[0,:,0])+list(perturb[:,0] - c[1,:,0])+list(perturb[:,0] - c[2,:,0])+list(perturb[:,1] - c[0,:,1])+list(perturb[:,1] - c[1,:,1])+list(perturb[:,1] - c[2,:,1])+list(perturb[:,2] - c[0,:,2])+list(perturb[:,2] - c[1,:,2])+list(perturb[:,2] - c[2,:,2])
            #print(len(calcs))
            fcs +=  calcs
            param_nm += ['b']*3*np.sum(g_filt)+['beta']*3*np.sum(g_filt)+['gamma']*3*np.sum(g_filt)
            cond_nm += [u]*9*np.sum(g_filt)
            means += list(s_means[i,g_filt])*9
            errs += list(sr_arr[i].sigma[g_filt,0])*3+list(sr_arr[i].sigma[g_filt,1])*3+list(sr_arr[i].sigma[g_filt,2])*3
            #var += [np.var(calcs[0:3])]*3+[np.var(calcs[3:6])]*3+[np.var(calcs[6:9])]*3
            #means_params += [np.mean(calcs[0:3])]*3+[np.mean(calcs[3:6])]*3+[np.mean(calcs[6:9])]*3
            genes_names += list(gene_names[g_filt])*9

fc_res = pd.DataFrame()
fc_res['FC'] = list(np.log2(10**(np.array(fcs))))
fc_res['Param'] = param_nm
fc_res['sgRNA'] = cond_nm
fc_res['meanS'] = means
fc_res['errs'] = errs
fc_res['Gene'] = genes_names
            
fc_res.head()
# Out:
# 2790
# 2911
#          FC Param        sgRNA     meanS      errs        Gene
# 0  0.032707     b  [CBL, CNN1]  0.207317  0.268927  AL592183.1
# 1  0.021378     b  [CBL, CNN1]  0.146341  0.186889      VPS13D
# 2 -0.143794     b  [CBL, CNN1]  0.195122  0.264211      TARBP1
# 3  0.063379     b  [CBL, CNN1]  1.715447  0.139588      HSPB11
# 4  0.693564     b  [CBL, CNN1]  0.219512  0.309607      KLHL20

# %%
fc_res.to_csv('bFC_allguides_cblcnn1_dusp9ets2_norman.csv',index=None)

# %%
fc_res[fc_res['Gene'].isin(['CNN1'])]
# Out:
#              FC  Param          sgRNA     meanS      errs  Gene
# 1253   4.659111      b    [CBL, CNN1]  2.703252  0.064481  CNN1
# 4043   4.135527      b    [CBL, CNN1]  2.703252  0.064481  CNN1
# 6833   3.910297      b    [CBL, CNN1]  2.703252  0.064481  CNN1
# 9623  -0.079310   beta    [CBL, CNN1]  2.703252  0.053296  CNN1
# 12413 -0.467929   beta    [CBL, CNN1]  2.703252  0.053296  CNN1
# 15203 -0.763129   beta    [CBL, CNN1]  2.703252  0.053296  CNN1
# 17993  0.088554  gamma    [CBL, CNN1]  2.703252  0.060854  CNN1
# 20783 -0.334553  gamma    [CBL, CNN1]  2.703252  0.060854  CNN1
# 23573 -0.587454  gamma    [CBL, CNN1]  2.703252  0.060854  CNN1
# 26425  0.403677      b  [DUSP9, ETS2]  0.089905  0.246052  CNN1
# 29336 -0.119907      b  [DUSP9, ETS2]  0.089905  0.246052  CNN1
# 32247 -0.345137      b  [DUSP9, ETS2]  0.089905  0.246052  CNN1
# 35158  0.392795   beta  [DUSP9, ETS2]  0.089905  0.231990  CNN1
# 38069  0.004176   beta  [DUSP9, ETS2]  0.089905  0.231990  CNN1
# 40980 -0.291024   beta  [DUSP9, ETS2]  0.089905  0.231990  CNN1
# 43891  0.759882  gamma  [DUSP9, ETS2]  0.089905  0.249781  CNN1
# 46802  0.336775  gamma  [DUSP9, ETS2]  0.089905  0.249781  CNN1
# 49713  0.083875  gamma  [DUSP9, ETS2]  0.089905  0.249781  CNN1

# %%
# sns.scatterplot(data=fish_df, x='No. Cells',y='beta Info',hue='Single Cond')
# plt.yscale('log')
# plt.xscale('log')
